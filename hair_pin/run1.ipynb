# %%
# %run main.py --ratio=0.3 --epochs=2 --local_ep=5 --lr=0.0001 --SampleRate=0.5 --local_bs=100 --test_unexampled=0
# Out:
# Experimental details:
#     Model     : mlp
#     Optimizer : adam
#     Learning  : 0.0001
#     Global Rounds   : 2
#
#     Federated parameters:
#     Fraction of users  : 0.1
#     Local Batch size   : 100
#     Local Epochs       : 5
#
# PyTorch is running on GPU: NVIDIA GeForce RTX 2080 Ti
# False
# Test model with the exampled 3th and 7th order filter
#   0%|          | 0/2 [00:00<?, ?it/s]
# | Global Round : 1 | Local Epoch : 1 | [0000/10400 (00.0%)]	Loss: 0.882567	R2: -0.010106
# | Global Round : 1 | Local Epoch : 1 | [10000/10400 (9.615384615384615%)]	Loss: 0.680350	R2: 0.377604
# [-0.010106498948315576, 0.37760390011960543]
# | Global Round : 1 | Local Epoch : 2 | [0000/10400 (00.0%)]	Loss: 0.618522	R2: 0.374569
# | Global Round : 1 | Local Epoch : 2 | [10000/10400 (9.615384615384615%)]	Loss: 0.408862	R2: 0.553144
# [-0.010106498948315576, 0.37760390011960543, 0.374569435713202, 0.5531442699930473]
# ...
